# %%
# !pip install streamlit==1.14.0
# !pip install streamlit-option-menu
# !pip install plotly_express
import streamlit as st
import pandas as pd
import altair as alt
# Out:
# Requirement already satisfied: streamlit==1.14.0 in c:\users\thahertech\anaconda3\lib\site-packages (1.14.0)
# Requirement already satisfied: cachetools>=4.0 in c:\users\thahertech\anaconda3\lib\site-packages (from streamlit==1.14.0) (4.2.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\thahertech\anaconda3\lib\site-packages (from streamlit==1.14.0) (9.0.1)
# Requirement already satisfied: pyarrow>=4.0 in c:\users\thahertech\anaconda3\lib\site-packages (from streamlit==1.14.0) (10.0.1)
# Requirement already satisfied: blinker>=1.0.0 in c:\users\thahertech\anaconda3\lib\site-packages (from streamlit==1.14.0) (1.5)
# Requirement already satisfied: click>=7.0 in c:\users\thahertech\anaconda3\lib\site-packages (from streamlit==1.14.0) (8.0.4)
# Requirement already satisfied: toml in c:\users\thahertech\anaconda3\lib\site-packages (from streamlit==1.14.0) (0.10.2)
# Requirement already satisfied: protobuf<4,>=3.12 in c:\users\thahertech\anaconda3\lib\site-packages (from streamlit==1.14.0) (3.19.1)
# Requirement already satisfied: numpy in c:\users\thahertech\anaconda3\lib\site-packages (from streamlit==1.14.0) (1.21.5)
# Requirement already satisfied: tzlocal>=1.1 in c:\users\thahertech\anaconda3\lib\site-packages (from streamlit==1.14.0) (4.2)
# Requirement already satisfied: watchdog in c:\users\thahertech\anaconda3\lib\site-packages (from streamlit==1.14.0) (2.1.6)
# Requirement already satisfied: pandas>=0.21.0 in c:\users\thahertech\anaconda3\lib\site-packages (from streamlit==1.14.0) (1.4.2)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in c:\users\thahertech\anaconda3\lib\site-packages (from streamlit==1.14.0) (4.1.1)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\thahertech\anaconda3\lib\site-packages (from streamlit==1.14.0) (4.11.3)
# Requirement already satisfied: requests>=2.4 in c:\users\thahertech\anaconda3\lib\site-packages (from streamlit==1.14.0) (2.27.1)
# Requirement already satisfied: altair>=3.2.0 in c:\users\thahertech\anaconda3\lib\site-packages (from streamlit==1.14.0) (4.2.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\thahertech\anaconda3\lib\site-packages (from streamlit==1.14.0) (12.6.0)
# Requirement already satisfied: gitpython!=3.1.19 in c:\users\thahertech\anaconda3\lib\site-packages (from streamlit==1.14.0) (3.1.29)
# Requirement already satisfied: pympler>=0.9 in c:\users\thahertech\anaconda3\lib\site-packages (from streamlit==1.14.0) (1.0.1)
# Requirement already satisfied: tornado>=5.0 in c:\users\thahertech\anaconda3\lib\site-packages (from streamlit==1.14.0) (6.1)
# Requirement already satisfied: python-dateutil in c:\users\thahertech\anaconda3\lib\site-packages (from streamlit==1.14.0) (2.8.2)
# Requirement already satisfied: validators>=0.2 in c:\users\thahertech\anaconda3\lib\site-packages (from streamlit==1.14.0) (0.20.0)
# Requirement already satisfied: pydeck>=0.1.dev5 in c:\users\thahertech\anaconda3\lib\site-packages (from streamlit==1.14.0) (0.8.0)
# Requirement already satisfied: semver in c:\users\thahertech\anaconda3\lib\site-packages (from streamlit==1.14.0) (2.13.0)
# Requirement already satisfied: packaging>=14.1 in c:\users\thahertech\anaconda3\lib\site-packages (from streamlit==1.14.0) (21.3)
# Requirement already satisfied: entrypoints in c:\users\thahertech\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit==1.14.0) (0.4)
# Requirement already satisfied: jinja2 in c:\users\thahertech\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit==1.14.0) (2.11.3)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\thahertech\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit==1.14.0) (4.4.0)
# Requirement already satisfied: toolz in c:\users\thahertech\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit==1.14.0) (0.11.2)
# Requirement already satisfied: colorama in c:\users\thahertech\anaconda3\lib\site-packages (from click>=7.0->streamlit==1.14.0) (0.4.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\thahertech\anaconda3\lib\site-packages (from gitpython!=3.1.19->streamlit==1.14.0) (4.0.10)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\thahertech\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit==1.14.0) (5.0.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\thahertech\anaconda3\lib\site-packages (from importlib-metadata>=1.4->streamlit==1.14.0) (3.7.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\thahertech\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit==1.14.0) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\thahertech\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit==1.14.0) (0.18.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\thahertech\anaconda3\lib\site-packages (from packaging>=14.1->streamlit==1.14.0) (3.0.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\thahertech\anaconda3\lib\site-packages (from pandas>=0.21.0->streamlit==1.14.0) (2021.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\thahertech\anaconda3\lib\site-packages (from jinja2->altair>=3.2.0->streamlit==1.14.0) (2.0.1)
# Requirement already satisfied: six>=1.5 in c:\users\thahertech\anaconda3\lib\site-packages (from python-dateutil->streamlit==1.14.0) (1.16.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\thahertech\anaconda3\lib\site-packages (from requests>=2.4->streamlit==1.14.0) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\thahertech\anaconda3\lib\site-packages (from requests>=2.4->streamlit==1.14.0) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\thahertech\anaconda3\lib\site-packages (from requests>=2.4->streamlit==1.14.0) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\thahertech\anaconda3\lib\site-packages (from requests>=2.4->streamlit==1.14.0) (2021.10.8)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in c:\users\thahertech\anaconda3\lib\site-packages (from rich>=10.11.0->streamlit==1.14.0) (2.11.2)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in c:\users\thahertech\anaconda3\lib\site-packages (from rich>=10.11.0->streamlit==1.14.0) (0.9.1)
# Requirement already satisfied: pytz-deprecation-shim in c:\users\thahertech\anaconda3\lib\site-packages (from tzlocal>=1.1->streamlit==1.14.0) (0.1.0.post0)
# Requirement already satisfied: tzdata in c:\users\thahertech\anaconda3\lib\site-packages (from tzlocal>=1.1->streamlit==1.14.0) (2022.7)
# Requirement already satisfied: decorator>=3.4.0 in c:\users\thahertech\anaconda3\lib\site-packages (from validators>=0.2->streamlit==1.14.0) (5.1.1)
# Collecting streamlit-option-menu
#   Downloading streamlit_option_menu-0.3.2-py3-none-any.whl (712 kB)
# Requirement already satisfied: streamlit>=0.63 in c:\users\thahertech\anaconda3\lib\site-packages (from streamlit-option-menu) (1.14.0)
# Requirement already satisfied: packaging>=14.1 in c:\users\thahertech\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit-option-menu) (21.3)
# Requirement already satisfied: semver in c:\users\thahertech\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit-option-menu) (2.13.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\thahertech\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit-option-menu) (9.0.1)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in c:\users\thahertech\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit-option-menu) (4.1.1)
# Requirement already satisfied: numpy in c:\users\thahertech\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit-option-menu) (1.21.5)
# Requirement already satisfied: validators>=0.2 in c:\users\thahertech\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit-option-menu) (0.20.0)
# Requirement already satisfied: tornado>=5.0 in c:\users\thahertech\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit-option-menu) (6.1)
# Requirement already satisfied: pyarrow>=4.0 in c:\users\thahertech\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit-option-menu) (10.0.1)
# Requirement already satisfied: click>=7.0 in c:\users\thahertech\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit-option-menu) (8.0.4)
# Requirement already satisfied: toml in c:\users\thahertech\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit-option-menu) (0.10.2)
# Requirement already satisfied: pydeck>=0.1.dev5 in c:\users\thahertech\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit-option-menu) (0.8.0)
# Requirement already satisfied: protobuf<4,>=3.12 in c:\users\thahertech\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit-option-menu) (3.19.1)
# Requirement already satisfied: cachetools>=4.0 in c:\users\thahertech\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit-option-menu) (4.2.2)
# Requirement already satisfied: pandas>=0.21.0 in c:\users\thahertech\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit-option-menu) (1.4.2)
# Requirement already satisfied: altair>=3.2.0 in c:\users\thahertech\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit-option-menu) (4.2.0)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\thahertech\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit-option-menu) (4.11.3)
# Requirement already satisfied: pympler>=0.9 in c:\users\thahertech\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit-option-menu) (1.0.1)
# Requirement already satisfied: gitpython!=3.1.19 in c:\users\thahertech\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit-option-menu) (3.1.29)
# Requirement already satisfied: rich>=10.11.0 in c:\users\thahertech\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit-option-menu) (12.6.0)
# Requirement already satisfied: tzlocal>=1.1 in c:\users\thahertech\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit-option-menu) (4.2)
# Requirement already satisfied: blinker>=1.0.0 in c:\users\thahertech\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit-option-menu) (1.5)
# Requirement already satisfied: watchdog in c:\users\thahertech\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit-option-menu) (2.1.6)
# Requirement already satisfied: requests>=2.4 in c:\users\thahertech\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit-option-menu) (2.27.1)
# Requirement already satisfied: python-dateutil in c:\users\thahertech\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit-option-menu) (2.8.2)
# Requirement already satisfied: jinja2 in c:\users\thahertech\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit>=0.63->streamlit-option-menu) (2.11.3)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\thahertech\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit>=0.63->streamlit-option-menu) (4.4.0)
# Requirement already satisfied: entrypoints in c:\users\thahertech\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit>=0.63->streamlit-option-menu) (0.4)
# Requirement already satisfied: toolz in c:\users\thahertech\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit>=0.63->streamlit-option-menu) (0.11.2)
# Requirement already satisfied: colorama in c:\users\thahertech\anaconda3\lib\site-packages (from click>=7.0->streamlit>=0.63->streamlit-option-menu) (0.4.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\thahertech\anaconda3\lib\site-packages (from gitpython!=3.1.19->streamlit>=0.63->streamlit-option-menu) (4.0.10)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\thahertech\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit>=0.63->streamlit-option-menu) (5.0.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\thahertech\anaconda3\lib\site-packages (from importlib-metadata>=1.4->streamlit>=0.63->streamlit-option-menu) (3.7.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\thahertech\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit>=0.63->streamlit-option-menu) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\thahertech\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit>=0.63->streamlit-option-menu) (21.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\thahertech\anaconda3\lib\site-packages (from packaging>=14.1->streamlit>=0.63->streamlit-option-menu) (3.0.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\thahertech\anaconda3\lib\site-packages (from pandas>=0.21.0->streamlit>=0.63->streamlit-option-menu) (2021.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\thahertech\anaconda3\lib\site-packages (from jinja2->altair>=3.2.0->streamlit>=0.63->streamlit-option-menu) (2.0.1)
# Requirement already satisfied: six>=1.5 in c:\users\thahertech\anaconda3\lib\site-packages (from python-dateutil->streamlit>=0.63->streamlit-option-menu) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\thahertech\anaconda3\lib\site-packages (from requests>=2.4->streamlit>=0.63->streamlit-option-menu) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\thahertech\anaconda3\lib\site-packages (from requests>=2.4->streamlit>=0.63->streamlit-option-menu) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\thahertech\anaconda3\lib\site-packages (from requests>=2.4->streamlit>=0.63->streamlit-option-menu) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\thahertech\anaconda3\lib\site-packages (from requests>=2.4->streamlit>=0.63->streamlit-option-menu) (2021.10.8)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in c:\users\thahertech\anaconda3\lib\site-packages (from rich>=10.11.0->streamlit>=0.63->streamlit-option-menu) (2.11.2)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in c:\users\thahertech\anaconda3\lib\site-packages (from rich>=10.11.0->streamlit>=0.63->streamlit-option-menu) (0.9.1)
# Requirement already satisfied: tzdata in c:\users\thahertech\anaconda3\lib\site-packages (from tzlocal>=1.1->streamlit>=0.63->streamlit-option-menu) (2022.7)
# Requirement already satisfied: pytz-deprecation-shim in c:\users\thahertech\anaconda3\lib\site-packages (from tzlocal>=1.1->streamlit>=0.63->streamlit-option-menu) (0.1.0.post0)
# Requirement already satisfied: decorator>=3.4.0 in c:\users\thahertech\anaconda3\lib\site-packages (from validators>=0.2->streamlit>=0.63->streamlit-option-menu) (5.1.1)
# Installing collected packages: streamlit-option-menu
# Successfully installed streamlit-option-menu-0.3.2
# Collecting plotly_express
#   Downloading plotly_express-0.4.1-py2.py3-none-any.whl (2.9 kB)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\thahertech\anaconda3\lib\site-packages (from plotly_express) (0.13.2)
# Requirement already satisfied: scipy>=0.18 in c:\users\thahertech\anaconda3\lib\site-packages (from plotly_express) (1.7.3)
# Requirement already satisfied: patsy>=0.5 in c:\users\thahertech\anaconda3\lib\site-packages (from plotly_express) (0.5.2)
# Requirement already satisfied: pandas>=0.20.0 in c:\users\thahertech\anaconda3\lib\site-packages (from plotly_express) (1.4.2)
# Requirement already satisfied: numpy>=1.11 in c:\users\thahertech\anaconda3\lib\site-packages (from plotly_express) (1.21.5)
# Requirement already satisfied: plotly>=4.1.0 in c:\users\thahertech\anaconda3\lib\site-packages (from plotly_express) (5.6.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\thahertech\anaconda3\lib\site-packages (from pandas>=0.20.0->plotly_express) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\thahertech\anaconda3\lib\site-packages (from pandas>=0.20.0->plotly_express) (2021.3)
# Requirement already satisfied: six in c:\users\thahertech\anaconda3\lib\site-packages (from patsy>=0.5->plotly_express) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\thahertech\anaconda3\lib\site-packages (from plotly>=4.1.0->plotly_express) (8.0.1)
# Requirement already satisfied: packaging>=21.3 in c:\users\thahertech\anaconda3\lib\site-packages (from statsmodels>=0.9.0->plotly_express) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\thahertech\anaconda3\lib\site-packages (from packaging>=21.3->statsmodels>=0.9.0->plotly_express) (3.0.4)
# Installing collected packages: plotly-express
# Successfully installed plotly-express-0.4.1

# %%
# %%writefile assignment2.py
import streamlit as st
import pandas as pd
import altair as alt
from streamlit_option_menu import option_menu
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.figure_factory as ff

#Steam = pd.read_csv('Steam.csv')
#st.set_page_config(
#  page_title="pages",
#)

page = st.sidebar.selectbox("Choose a page", ["Introduction", "Scatter and Line", "Pie and area chart and bar"])
if page == "Introduction":
  Steam = pd.read_csv('Steam.csv')
  # title
  st.title('Steam Games Application')
  st.sidebar.success("Select a page above.")
  st.markdown('Introduction')
  st.text('The dataset includes information on the games')
  st.text('Metacritic score')
  st.text('price')
  st.text('number of recommendations')
  st.text('Using this data you can analyze which games are the most popular on Steam')
  st.text('and compare their prices and Metacritic scores')
  st.text('You can also use the data to find games that are recommended by other Steam users')
  st.text('Recently some players used to get bored or confused which game to play or invest their time or money in')
  st.text('so using the following informations will make the choices easier')
  st.markdown('Findings')
  st.write('The games counter strike and half time are the most played of all time and have the highest recommendations numbers.')
  def convert_df(df):
    return df.to_csv().encode('utf-8')
  csv = convert_df(Steam)
  st.download_button(
    label="Download dataset as CSV",
    data=csv,
    file_name='steamgames_dataset.csv',
    mime='text/csv',)

if page == "Scatter and Line":
  Steam = pd.read_csv('Steam.csv')
  games_name = st.selectbox("Select your game",Steam['ResponseName'].unique())
  st.write(games_name)
  plot_type=st.checkbox("plot type scatter")
  plot_type1=st.checkbox("plot type line")
  if plot_type:
    pl = alt.Chart(Steam[Steam['ResponseName']==games_name]).mark_circle().encode(
      x = 'ResponseName',
      y ='PriceInitial',
      color = 'ResponseName',
      tooltip = ['ResponseName','PriceInitial']
  ).interactive()
    st.altair_chart(pl)
  if plot_type1:
    pl = alt.Chart(Steam.head(10)).mark_line().encode(
      x = 'ResponseName',
      y ='PriceInitial',
      color = 'ResponseName',
      tooltip = ['ResponseName','PriceInitial']
  ).interactive()
    st.altair_chart(pl)

if page == "Pie and area chart and bar":
  Steam = pd.read_csv('Steam.csv')

  # 2. horizontal menu
  selected2 = option_menu(None, ["area_chart/pie", "Bar"], 
    menu_icon="cast", default_index=0, orientation="horizontal")

  if selected2 == "area_chart/pie":
    plot_type=st.radio("select the plot type",['area_chart','pie'])
    
    if plot_type == 'area_chart':
      st.area_chart(data=Steam.head(10), x='PriceInitial', y='ResponseName')

    if plot_type == 'pie':
      st.subheader('Pie chart')
      f1, ax1 = plt.subplots()
      ax1.pie(Steam['PriceInitial'].head(10), labels=Steam['ResponseName'].head(10), autopct='%1.1f%%',shadow=True, startangle=90)
      ax1.axis('equal')
      st.pyplot(f1)
    
  else:
    option = ['Bar']
    selected_option = st.multiselect("Select any chart to see", option)
    for o in selected_option:
      if o == 'Bar':
        pl = alt.Chart(Steam.head(10)).mark_bar().encode(
        x = 'Metacritic',
        y = 'PriceInitial',
        color = 'ResponseName',
        tooltip = ['Metacritic','PriceInitial']
        ).interactive()
        st.altair_chart(pl)
# Out:
# Overwriting assignment2.py
